# %% [markdown]
# <a href="https://colab.research.google.com/github/dhawalnegi1/EVA/blob/master/ASSINGMENT-6/Assignment6_Dense.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from keras import backend as K
import time
import matplotlib.pyplot as plt
import numpy as np
% matplotlib inline
np.random.seed(2017) 
from keras.models import Sequential
from keras.layers.convolutional import Convolution2D, MaxPooling2D
from keras.layers import Activation, Flatten, Dense, Dropout
from keras.layers.normalization import BatchNormalization
from keras.utils import np_utils
# Out:
# Using TensorFlow backend.

# %%
from keras.datasets import cifar10
(train_features, train_labels), (test_features, test_labels) = cifar10.load_data()
num_train, img_channels, img_rows, img_cols =  train_features.shape
num_test, _, _, _ =  test_features.shape
num_classes = len(np.unique(train_labels))

# %%
class_names = ['airplane','automobile','bird','cat','deer',
               'dog','frog','horse','ship','truck']
fig = plt.figure(figsize=(8,3))
for i in range(num_classes):
    ax = fig.add_subplot(2, 5, 1 + i, xticks=[], yticks=[])
    idx = np.where(train_labels[:]==i)[0]
    features_idx = train_features[idx,::]
    img_num = np.random.randint(features_idx.shape[0])
    im = features_idx[img_num]
    ax.set_title(class_names[i])
    plt.imshow(im)
plt.show()

# %%
def plot_model_history(model_history):
    fig, axs = plt.subplots(1,2,figsize=(15,5))
    # summarize history for accuracy
    axs[0].plot(range(1,len(model_history.history['acc'])+1),model_history.history['acc'])
    axs[0].plot(range(1,len(model_history.history['val_acc'])+1),model_history.history['val_acc'])
    axs[0].set_title('Model Accuracy')
    axs[0].set_ylabel('Accuracy')
    axs[0].set_xlabel('Epoch')
    axs[0].set_xticks(np.arange(1,len(model_history.history['acc'])+1),len(model_history.history['acc'])/10)
    axs[0].legend(['train', 'val'], loc='best')
    # summarize history for loss
    axs[1].plot(range(1,len(model_history.history['loss'])+1),model_history.history['loss'])
    axs[1].plot(range(1,len(model_history.history['val_loss'])+1),model_history.history['val_loss'])
    axs[1].set_title('Model Loss')
    axs[1].set_ylabel('Loss')
    axs[1].set_xlabel('Epoch')
    axs[1].set_xticks(np.arange(1,len(model_history.history['loss'])+1),len(model_history.history['loss'])/10)
    axs[1].legend(['train', 'val'], loc='best')
    plt.show()

# %%
def accuracy(test_x, test_y, model):
    result = model.predict(test_x)
    predicted_class = np.argmax(result, axis=1)
    true_class = np.argmax(test_y, axis=1)
    num_correct = np.sum(predicted_class == true_class) 
    accuracy = float(num_correct)/result.shape[0]
    return (accuracy * 100)

# %%
train_features = train_features.astype('float32')/255
test_features = test_features.astype('float32')/255
# convert class labels to binary class labels
train_labels = np_utils.to_categorical(train_labels, num_classes)
test_labels = np_utils.to_categorical(test_labels, num_classes)

# %%
# Define the model
model = Sequential()
model.add(Convolution2D(48, 3, 3, border_mode='same', input_shape=(32, 32, 3)))
model.add(Activation('relu'))
model.add(Convolution2D(48, 3, 3))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))
model.add(Convolution2D(96, 3, 3, border_mode='same'))
model.add(Activation('relu'))
model.add(Convolution2D(96, 3, 3))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))
model.add(Convolution2D(192, 3, 3, border_mode='same'))
model.add(Activation('relu'))
model.add(Convolution2D(192, 3, 3))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))
model.add(Flatten())
model.add(Dense(512))
model.add(Activation('relu'))
model.add(Dropout(0.5))
model.add(Dense(256))
model.add(Activation('relu'))
model.add(Dropout(0.5))
model.add(Dense(num_classes, activation='softmax'))
# Compile the model
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3445: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:2: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(48, (3, 3), input_shape=(32, 32, 3..., padding="same")`
#
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:4: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(48, (3, 3))`
#   after removing the cwd from sys.path.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:8: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(96, (3, 3), padding="same")`
#
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:10: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(96, (3, 3))`
#   # Remove the CWD from sys.path while we load stuff.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:14: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(192, (3, 3), padding="same")`
#
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:16: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(192, (3, 3))`
#   app.launch_new_instance()

# %%
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 32, 32, 48)        1344
# _________________________________________________________________
# activation_1 (Activation)    (None, 32, 32, 48)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 30, 30, 48)        20784
# _________________________________________________________________
# activation_2 (Activation)    (None, 30, 30, 48)        0
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 15, 15, 48)        0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 15, 15, 48)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 15, 15, 96)        41568
# _________________________________________________________________
# activation_3 (Activation)    (None, 15, 15, 96)        0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 13, 13, 96)        83040
# _________________________________________________________________
# activation_4 (Activation)    (None, 13, 13, 96)        0
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 6, 6, 96)          0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 6, 6, 96)          0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 6, 6, 192)         166080
# _________________________________________________________________
# activation_5 (Activation)    (None, 6, 6, 192)         0
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 4, 4, 192)         331968
# _________________________________________________________________
# activation_6 (Activation)    (None, 4, 4, 192)         0
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 2, 2, 192)         0
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 2, 2, 192)         0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 768)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 512)               393728
# _________________________________________________________________
# activation_7 (Activation)    (None, 512)               0
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 256)               131328
# _________________________________________________________________
# activation_8 (Activation)    (None, 256)               0
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 10)                2570
# =================================================================
# Total params: 1,172,410
# Trainable params: 1,172,410
# Non-trainable params: 0
# _________________________________________________________________

# %%
from keras.preprocessing.image import ImageDataGenerator

datagen = ImageDataGenerator(zoom_range=0.0, 
                             horizontal_flip=False)

from keras.optimizers import Adam
from keras.callbacks import LearningRateScheduler, ModelCheckpoint
# train the model
start = time.time()
# Train the model
filepath="saved1.hdf5"
checkpoint = ModelCheckpoint(filepath, monitor='val_acc', verbose=1, save_best_only=True, mode='max')
callbacks_list = [checkpoint]
model_info = model.fit_generator(datagen.flow(train_features, train_labels, batch_size = 128),
                                 samples_per_epoch = train_features.shape[0], nb_epoch = 100, 
                                 validation_data = (test_features, test_labels),callbacks= callbacks_list, verbose=1)
end = time.time()
print ("Model took %0.2f seconds to train"%(end - start))
# plot model history
plot_model_history(model_info)
# compute test accuracy
print ("Accuracy on test data is: %0.2f"%accuracy(test_features, test_labels, model))
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:16: UserWarning: The semantics of the Keras 2 argument `steps_per_epoch` is not the same as the Keras 1 argument `samples_per_epoch`. `steps_per_epoch` is the number of batches to draw from the generator at each epoch. Basically steps_per_epoch = samples_per_epoch/batch_size. Similarly `nb_val_samples`->`validation_steps` and `val_samples`->`steps` arguments have changed. Update your method calls accordingly.
#   app.launch_new_instance()
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:16: UserWarning: Update your `fit_generator` call to the Keras 2 API: `fit_generator(<keras_pre..., validation_data=(array([[[..., callbacks=[<keras.ca..., verbose=1, steps_per_epoch=390, epochs=100)`
#   app.launch_new_instance()
# Epoch 1/100
# 390/390 [==============================] - 13s 34ms/step - loss: 1.8700 - acc: 0.2832 - val_loss: 1.4731 - val_acc: 0.4559
#
# Epoch 00001: val_acc improved from -inf to 0.45590, saving model to saved1.hdf5
# Epoch 2/100
# 390/390 [==============================] - 9s 23ms/step - loss: 1.3633 - acc: 0.5023 - val_loss: 1.1298 - val_acc: 0.5941
#
# Epoch 00002: val_acc improved from 0.45590 to 0.59410, saving model to saved1.hdf5
# Epoch 3/100
# 390/390 [==============================] - 9s 23ms/step - loss: 1.1297 - acc: 0.6028 - val_loss: 0.9906 - val_acc: 0.6469
#
# Epoch 00003: val_acc improved from 0.59410 to 0.64690, saving model to saved1.hdf5
# Epoch 4/100
# 390/390 [==============================] - 9s 23ms/step - loss: 0.9756 - acc: 0.6556 - val_loss: 0.8984 - val_acc: 0.6852
#
# Epoch 00004: val_acc improved from 0.64690 to 0.68520, saving model to saved1.hdf5
# Epoch 5/100
# 390/390 [==============================] - 9s 23ms/step - loss: 0.8850 - acc: 0.6917 - val_loss: 0.7981 - val_acc: 0.7196
#
# Epoch 00005: val_acc improved from 0.68520 to 0.71960, saving model to saved1.hdf5
# Epoch 6/100
# 390/390 [==============================] - 9s 23ms/step - loss: 0.8085 - acc: 0.7213 - val_loss: 0.7686 - val_acc: 0.7355
#
# Epoch 00006: val_acc improved from 0.71960 to 0.73550, saving model to saved1.hdf5
# Epoch 7/100
# 390/390 [==============================] - 9s 23ms/step - loss: 0.7549 - acc: 0.7404 - val_loss: 0.7459 - val_acc: 0.7493
#
# Epoch 00007: val_acc improved from 0.73550 to 0.74930, saving model to saved1.hdf5
# Epoch 8/100
# 390/390 [==============================] - 9s 23ms/step - loss: 0.6987 - acc: 0.7611 - val_loss: 0.6997 - val_acc: 0.7593
#
# Epoch 00008: val_acc improved from 0.74930 to 0.75930, saving model to saved1.hdf5
# Epoch 9/100
# 390/390 [==============================] - 9s 23ms/step - loss: 0.6742 - acc: 0.7692 - val_loss: 0.6469 - val_acc: 0.7801
#
# Epoch 00009: val_acc improved from 0.75930 to 0.78010, saving model to saved1.hdf5
# Epoch 10/100
# 390/390 [==============================] - 9s 23ms/step - loss: 0.6381 - acc: 0.7827 - val_loss: 0.6548 - val_acc: 0.7798
#
# Epoch 00010: val_acc did not improve from 0.78010
# Epoch 11/100
# 390/390 [==============================] - 9s 23ms/step - loss: 0.6129 - acc: 0.7903 - val_loss: 0.6629 - val_acc: 0.7797
#
# Epoch 00011: val_acc did not improve from 0.78010
# Epoch 12/100
# 390/390 [==============================] - 9s 23ms/step - loss: 0.5902 - acc: 0.7981 - val_loss: 0.6048 - val_acc: 0.7965
#
# Epoch 00012: val_acc improved from 0.78010 to 0.79650, saving model to saved1.hdf5
# Epoch 13/100
# 390/390 [==============================] - 9s 23ms/step - loss: 0.5671 - acc: 0.8074 - val_loss: 0.6153 - val_acc: 0.7940
#
# Epoch 00013: val_acc did not improve from 0.79650
# Epoch 14/100
# 390/390 [==============================] - 9s 23ms/step - loss: 0.5494 - acc: 0.8127 - val_loss: 0.6021 - val_acc: 0.7983
#
# Epoch 00014: val_acc improved from 0.79650 to 0.79830, saving model to saved1.hdf5
# Epoch 15/100
# 390/390 [==============================] - 9s 23ms/step - loss: 0.5421 - acc: 0.8135 - val_loss: 0.5930 - val_acc: 0.8041
#
# Epoch 00015: val_acc improved from 0.79830 to 0.80410, saving model to saved1.hdf5
# Epoch 16/100
# 390/390 [==============================] - 9s 23ms/step - loss: 0.5178 - acc: 0.8226 - val_loss: 0.5891 - val_acc: 0.8045
#
# Epoch 00016: val_acc improved from 0.80410 to 0.80450, saving model to saved1.hdf5
# Epoch 17/100
# 390/390 [==============================] - 9s 23ms/step - loss: 0.5004 - acc: 0.8312 - val_loss: 0.6090 - val_acc: 0.7971
#
# Epoch 00017: val_acc did not improve from 0.80450
# Epoch 18/100
# 390/390 [==============================] - 9s 23ms/step - loss: 0.4944 - acc: 0.8323 - val_loss: 0.6063 - val_acc: 0.8059
#
# Epoch 00018: val_acc improved from 0.80450 to 0.80590, saving model to saved1.hdf5
# Epoch 19/100
# 390/390 [==============================] - 9s 23ms/step - loss: 0.4705 - acc: 0.8393 - val_loss: 0.5701 - val_acc: 0.8156
#
# Epoch 00019: val_acc improved from 0.80590 to 0.81560, saving model to saved1.hdf5
# Epoch 20/100
# 390/390 [==============================] - 9s 23ms/step - loss: 0.4699 - acc: 0.8396 - val_loss: 0.6121 - val_acc: 0.8103
#
# Epoch 00020: val_acc did not improve from 0.81560
# Epoch 21/100
# 390/390 [==============================] - 9s 23ms/step - loss: 0.4444 - acc: 0.8483 - val_loss: 0.5623 - val_acc: 0.8193
#
# Epoch 00021: val_acc improved from 0.81560 to 0.81930, saving model to saved1.hdf5
# Epoch 22/100
# 390/390 [==============================] - 9s 23ms/step - loss: 0.4435 - acc: 0.8485 - val_loss: 0.5713 - val_acc: 0.8161
#
# Epoch 00022: val_acc did not improve from 0.81930
# Epoch 23/100
# 390/390 [==============================] - 9s 23ms/step - loss: 0.4437 - acc: 0.8492 - val_loss: 0.5853 - val_acc: 0.8150
#
# Epoch 00023: val_acc did not improve from 0.81930
# Epoch 24/100
# 390/390 [==============================] - 9s 23ms/step - loss: 0.4387 - acc: 0.8505 - val_loss: 0.5958 - val_acc: 0.8128
#
# Epoch 00024: val_acc did not improve from 0.81930
# Epoch 25/100
# 390/390 [==============================] - 9s 23ms/step - loss: 0.4196 - acc: 0.8582 - val_loss: 0.5795 - val_acc: 0.8178
#
# Epoch 00025: val_acc did not improve from 0.81930
# Epoch 26/100
# 390/390 [==============================] - 9s 23ms/step - loss: 0.4180 - acc: 0.8586 - val_loss: 0.6035 - val_acc: 0.8097
#
# Epoch 00026: val_acc did not improve from 0.81930
# Epoch 27/100
# 390/390 [==============================] - 9s 23ms/step - loss: 0.4057 - acc: 0.8624 - val_loss: 0.5756 - val_acc: 0.8183
#
# Epoch 00027: val_acc did not improve from 0.81930
# Epoch 28/100
# 390/390 [==============================] - 9s 23ms/step - loss: 0.4093 - acc: 0.8619 - val_loss: 0.5924 - val_acc: 0.8120
#
# Epoch 00028: val_acc did not improve from 0.81930
# Epoch 29/100
# 390/390 [==============================] - 9s 23ms/step - loss: 0.3950 - acc: 0.8664 - val_loss: 0.5659 - val_acc: 0.8205
#
# Epoch 00029: val_acc improved from 0.81930 to 0.82050, saving model to saved1.hdf5
# Epoch 30/100
# 390/390 [==============================] - 9s 23ms/step - loss: 0.3864 - acc: 0.8693 - val_loss: 0.6255 - val_acc: 0.8106
#
# Epoch 00030: val_acc did not improve from 0.82050
# Epoch 31/100
# 390/390 [==============================] - 9s 23ms/step - loss: 0.3865 - acc: 0.8687 - val_loss: 0.5788 - val_acc: 0.8178
#
# Epoch 00031: val_acc did not improve from 0.82050
# Epoch 32/100
# 390/390 [==============================] - 9s 23ms/step - loss: 0.3743 - acc: 0.8724 - val_loss: 0.5976 - val_acc: 0.8172
#
# Epoch 00032: val_acc did not improve from 0.82050
# Epoch 33/100
# 390/390 [==============================] - 9s 23ms/step - loss: 0.3688 - acc: 0.8744 - val_loss: 0.5935 - val_acc: 0.8183
#
# Epoch 00033: val_acc did not improve from 0.82050
# Epoch 34/100
# 390/390 [==============================] - 9s 23ms/step - loss: 0.3687 - acc: 0.8778 - val_loss: 0.5897 - val_acc: 0.8208
#
# Epoch 00034: val_acc improved from 0.82050 to 0.82080, saving model to saved1.hdf5
# Epoch 35/100
# 390/390 [==============================] - 9s 23ms/step - loss: 0.3620 - acc: 0.8767 - val_loss: 0.5872 - val_acc: 0.8221
#
# Epoch 00035: val_acc improved from 0.82080 to 0.82210, saving model to saved1.hdf5
# Epoch 36/100
# 390/390 [==============================] - 9s 23ms/step - loss: 0.3702 - acc: 0.8759 - val_loss: 0.5921 - val_acc: 0.8233
#
# Epoch 00036: val_acc improved from 0.82210 to 0.82330, saving model to saved1.hdf5
# Epoch 37/100
# 390/390 [==============================] - 9s 23ms/step - loss: 0.3603 - acc: 0.8779 - val_loss: 0.5693 - val_acc: 0.8171
#
# Epoch 00037: val_acc did not improve from 0.82330
# Epoch 38/100
# 390/390 [==============================] - 9s 23ms/step - loss: 0.3554 - acc: 0.8795 - val_loss: 0.5862 - val_acc: 0.8201
#
# Epoch 00038: val_acc did not improve from 0.82330
# Epoch 39/100
# 390/390 [==============================] - 9s 23ms/step - loss: 0.3558 - acc: 0.8797 - val_loss: 0.5988 - val_acc: 0.8206
#
# Epoch 00039: val_acc did not improve from 0.82330
# Epoch 40/100
# 390/390 [==============================] - 9s 23ms/step - loss: 0.3445 - acc: 0.8846 - val_loss: 0.5896 - val_acc: 0.8189
#
# Epoch 00040: val_acc did not improve from 0.82330
# Epoch 41/100
# 390/390 [==============================] - 9s 23ms/step - loss: 0.3407 - acc: 0.8860 - val_loss: 0.6039 - val_acc: 0.8221
#
# Epoch 00041: val_acc did not improve from 0.82330
# Epoch 42/100
# 390/390 [==============================] - 9s 23ms/step - loss: 0.3385 - acc: 0.8851 - val_loss: 0.5875 - val_acc: 0.8267
#
# Epoch 00042: val_acc improved from 0.82330 to 0.82670, saving model to saved1.hdf5
# Epoch 43/100
# 390/390 [==============================] - 9s 23ms/step - loss: 0.3400 - acc: 0.8848 - val_loss: 0.5782 - val_acc: 0.8220
#
# Epoch 00043: val_acc did not improve from 0.82670
# Epoch 44/100
# 390/390 [==============================] - 9s 23ms/step - loss: 0.3357 - acc: 0.8867 - val_loss: 0.5557 - val_acc: 0.8270
#
# Epoch 00044: val_acc improved from 0.82670 to 0.82700, saving model to saved1.hdf5
# Epoch 45/100
# 390/390 [==============================] - 9s 23ms/step - loss: 0.3291 - acc: 0.8884 - val_loss: 0.5846 - val_acc: 0.8189
#
# Epoch 00045: val_acc did not improve from 0.82700
# Epoch 46/100
# 390/390 [==============================] - 9s 23ms/step - loss: 0.3279 - acc: 0.8896 - val_loss: 0.6070 - val_acc: 0.8223
#
# Epoch 00046: val_acc did not improve from 0.82700
# Epoch 47/100
# 390/390 [==============================] - 9s 23ms/step - loss: 0.3228 - acc: 0.8907 - val_loss: 0.6314 - val_acc: 0.8133
#
# Epoch 00047: val_acc did not improve from 0.82700
# Epoch 48/100
# 390/390 [==============================] - 9s 23ms/step - loss: 0.3187 - acc: 0.8935 - val_loss: 0.5803 - val_acc: 0.8270
#
# Epoch 00048: val_acc did not improve from 0.82700
# Epoch 49/100
# 390/390 [==============================] - 9s 23ms/step - loss: 0.3213 - acc: 0.8931 - val_loss: 0.5997 - val_acc: 0.8270
#
# Epoch 00049: val_acc did not improve from 0.82700
# Epoch 50/100
# 390/390 [==============================] - 9s 23ms/step - loss: 0.3202 - acc: 0.8934 - val_loss: 0.5929 - val_acc: 0.8200
#
# Epoch 00050: val_acc did not improve from 0.82700
# Epoch 51/100
# 390/390 [==============================] - 9s 23ms/step - loss: 0.3214 - acc: 0.8935 - val_loss: 0.5665 - val_acc: 0.8287
#
# Epoch 00051: val_acc improved from 0.82700 to 0.82870, saving model to saved1.hdf5
# Epoch 52/100
# 390/390 [==============================] - 9s 23ms/step - loss: 0.3057 - acc: 0.8984 - val_loss: 0.5897 - val_acc: 0.8279
#
# Epoch 00052: val_acc did not improve from 0.82870
# Epoch 53/100
# 390/390 [==============================] - 9s 23ms/step - loss: 0.3088 - acc: 0.8966 - val_loss: 0.5799 - val_acc: 0.8309
#
# Epoch 00053: val_acc improved from 0.82870 to 0.83090, saving model to saved1.hdf5
# Epoch 54/100
# 390/390 [==============================] - 9s 23ms/step - loss: 0.3095 - acc: 0.8983 - val_loss: 0.5897 - val_acc: 0.8306
#
# Epoch 00054: val_acc did not improve from 0.83090
# Epoch 55/100
# 390/390 [==============================] - 9s 23ms/step - loss: 0.3013 - acc: 0.9009 - val_loss: 0.6201 - val_acc: 0.8201
#
# Epoch 00055: val_acc did not improve from 0.83090
# Epoch 56/100
# 390/390 [==============================] - 9s 23ms/step - loss: 0.3070 - acc: 0.8989 - val_loss: 0.6069 - val_acc: 0.8312
#
# Epoch 00056: val_acc improved from 0.83090 to 0.83120, saving model to saved1.hdf5
# Epoch 57/100
# 390/390 [==============================] - 9s 23ms/step - loss: 0.3102 - acc: 0.8971 - val_loss: 0.6094 - val_acc: 0.8299
#
# Epoch 00057: val_acc did not improve from 0.83120
# Epoch 58/100
# 390/390 [==============================] - 9s 23ms/step - loss: 0.3013 - acc: 0.9019 - val_loss: 0.5715 - val_acc: 0.8295
#
# Epoch 00058: val_acc did not improve from 0.83120
# Epoch 59/100
# 390/390 [==============================] - 9s 23ms/step - loss: 0.2954 - acc: 0.9026 - val_loss: 0.5876 - val_acc: 0.8322
#
# Epoch 00059: val_acc improved from 0.83120 to 0.83220, saving model to saved1.hdf5
# Epoch 60/100
# 390/390 [==============================] - 9s 23ms/step - loss: 0.2903 - acc: 0.9037 - val_loss: 0.5983 - val_acc: 0.8341
#
# Epoch 00060: val_acc improved from 0.83220 to 0.83410, saving model to saved1.hdf5
# Epoch 61/100
# 390/390 [==============================] - 9s 23ms/step - loss: 0.2992 - acc: 0.9018 - val_loss: 0.5886 - val_acc: 0.8257
#
# Epoch 00061: val_acc did not improve from 0.83410
# Epoch 62/100
# 390/390 [==============================] - 9s 23ms/step - loss: 0.2891 - acc: 0.9049 - val_loss: 0.6143 - val_acc: 0.8296
#
# Epoch 00062: val_acc did not improve from 0.83410
# Epoch 63/100
# 390/390 [==============================] - 9s 23ms/step - loss: 0.2876 - acc: 0.9061 - val_loss: 0.6133 - val_acc: 0.8257
#
# Epoch 00063: val_acc did not improve from 0.83410
# Epoch 64/100
# 390/390 [==============================] - 9s 23ms/step - loss: 0.2935 - acc: 0.9059 - val_loss: 0.5977 - val_acc: 0.8333
#
# Epoch 00064: val_acc did not improve from 0.83410
# Epoch 65/100
# 390/390 [==============================] - 9s 23ms/step - loss: 0.2966 - acc: 0.9037 - val_loss: 0.5796 - val_acc: 0.8290
#
# Epoch 00065: val_acc did not improve from 0.83410
# Epoch 66/100
# 390/390 [==============================] - 9s 23ms/step - loss: 0.2894 - acc: 0.9063 - val_loss: 0.6130 - val_acc: 0.8264
#
# Epoch 00066: val_acc did not improve from 0.83410
# Epoch 67/100
# 390/390 [==============================] - 9s 23ms/step - loss: 0.2839 - acc: 0.9068 - val_loss: 0.6046 - val_acc: 0.8306
#
# Epoch 00067: val_acc did not improve from 0.83410
# Epoch 68/100
# 390/390 [==============================] - 9s 23ms/step - loss: 0.2748 - acc: 0.9105 - val_loss: 0.6047 - val_acc: 0.8311
#
# Epoch 00068: val_acc did not improve from 0.83410
# Epoch 69/100
# 390/390 [==============================] - 9s 23ms/step - loss: 0.2814 - acc: 0.9083 - val_loss: 0.6076 - val_acc: 0.8289
#
# Epoch 00069: val_acc did not improve from 0.83410
# Epoch 70/100
# 390/390 [==============================] - 9s 23ms/step - loss: 0.2814 - acc: 0.9110 - val_loss: 0.6040 - val_acc: 0.8332
#
# Epoch 00070: val_acc did not improve from 0.83410
# Epoch 71/100
# 390/390 [==============================] - 9s 23ms/step - loss: 0.2761 - acc: 0.9098 - val_loss: 0.6241 - val_acc: 0.8274
#
# Epoch 00071: val_acc did not improve from 0.83410
# Epoch 72/100
# 390/390 [==============================] - 9s 23ms/step - loss: 0.2775 - acc: 0.9093 - val_loss: 0.6116 - val_acc: 0.8311
#
# Epoch 00072: val_acc did not improve from 0.83410
# Epoch 73/100
# 390/390 [==============================] - 9s 23ms/step - loss: 0.2817 - acc: 0.9094 - val_loss: 0.6064 - val_acc: 0.8250
#
# Epoch 00073: val_acc did not improve from 0.83410
# Epoch 74/100
# 390/390 [==============================] - 9s 23ms/step - loss: 0.2702 - acc: 0.9134 - val_loss: 0.6258 - val_acc: 0.8323
#
# Epoch 00074: val_acc did not improve from 0.83410
# Epoch 75/100
# 390/390 [==============================] - 9s 23ms/step - loss: 0.2726 - acc: 0.9125 - val_loss: 0.6151 - val_acc: 0.8275
#
# Epoch 00075: val_acc did not improve from 0.83410
# Epoch 76/100
# 390/390 [==============================] - 9s 23ms/step - loss: 0.2786 - acc: 0.9111 - val_loss: 0.6246 - val_acc: 0.8258
#
# Epoch 00076: val_acc did not improve from 0.83410
# Epoch 77/100
# 390/390 [==============================] - 9s 23ms/step - loss: 0.2778 - acc: 0.9119 - val_loss: 0.6089 - val_acc: 0.8304
#
# Epoch 00077: val_acc did not improve from 0.83410
# Epoch 78/100
# 390/390 [==============================] - 9s 23ms/step - loss: 0.2740 - acc: 0.9106 - val_loss: 0.6043 - val_acc: 0.8311
#
# Epoch 00078: val_acc did not improve from 0.83410
# Epoch 79/100
# 390/390 [==============================] - 9s 23ms/step - loss: 0.2672 - acc: 0.9153 - val_loss: 0.6490 - val_acc: 0.8263
#
# Epoch 00079: val_acc did not improve from 0.83410
# Epoch 80/100
# 390/390 [==============================] - 9s 23ms/step - loss: 0.2608 - acc: 0.9154 - val_loss: 0.6067 - val_acc: 0.8350
#
# Epoch 00080: val_acc improved from 0.83410 to 0.83500, saving model to saved1.hdf5
# Epoch 81/100
# 390/390 [==============================] - 9s 23ms/step - loss: 0.2817 - acc: 0.9096 - val_loss: 0.6222 - val_acc: 0.8327
#
# Epoch 00081: val_acc did not improve from 0.83500
# Epoch 82/100
# 390/390 [==============================] - 9s 23ms/step - loss: 0.2639 - acc: 0.9179 - val_loss: 0.6141 - val_acc: 0.8335
#
# Epoch 00082: val_acc did not improve from 0.83500
# Epoch 83/100
# 390/390 [==============================] - 9s 23ms/step - loss: 0.2644 - acc: 0.9160 - val_loss: 0.6343 - val_acc: 0.8275
#
# Epoch 00083: val_acc did not improve from 0.83500
# Epoch 84/100
# 390/390 [==============================] - 9s 23ms/step - loss: 0.2561 - acc: 0.9175 - val_loss: 0.6228 - val_acc: 0.8298
#
# Epoch 00084: val_acc did not improve from 0.83500
# Epoch 85/100
# 390/390 [==============================] - 9s 23ms/step - loss: 0.2675 - acc: 0.9151 - val_loss: 0.6651 - val_acc: 0.8267
#
# Epoch 00085: val_acc did not improve from 0.83500
# Epoch 86/100
# 390/390 [==============================] - 9s 23ms/step - loss: 0.2559 - acc: 0.9178 - val_loss: 0.6663 - val_acc: 0.8261
#
# Epoch 00086: val_acc did not improve from 0.83500
# Epoch 87/100
# 390/390 [==============================] - 9s 23ms/step - loss: 0.2657 - acc: 0.9154 - val_loss: 0.6098 - val_acc: 0.8328
#
# Epoch 00087: val_acc did not improve from 0.83500
# Epoch 88/100
# 390/390 [==============================] - 9s 23ms/step - loss: 0.2442 - acc: 0.9216 - val_loss: 0.6228 - val_acc: 0.8300
#
# Epoch 00088: val_acc did not improve from 0.83500
# Epoch 89/100
# 390/390 [==============================] - 9s 23ms/step - loss: 0.2640 - acc: 0.9150 - val_loss: 0.6177 - val_acc: 0.8361
#
# Epoch 00089: val_acc improved from 0.83500 to 0.83610, saving model to saved1.hdf5
# Epoch 90/100
# 390/390 [==============================] - 9s 23ms/step - loss: 0.2493 - acc: 0.9197 - val_loss: 0.6211 - val_acc: 0.8331
#
# Epoch 00090: val_acc did not improve from 0.83610
# Epoch 91/100
# 390/390 [==============================] - 9s 23ms/step - loss: 0.2570 - acc: 0.9174 - val_loss: 0.6201 - val_acc: 0.8284
#
# Epoch 00091: val_acc did not improve from 0.83610
# Epoch 92/100
# 390/390 [==============================] - 9s 23ms/step - loss: 0.2560 - acc: 0.9211 - val_loss: 0.6093 - val_acc: 0.8338
#
# Epoch 00092: val_acc did not improve from 0.83610
# Epoch 93/100
# 390/390 [==============================] - 9s 23ms/step - loss: 0.2529 - acc: 0.9204 - val_loss: 0.6434 - val_acc: 0.8296
#
# Epoch 00093: val_acc did not improve from 0.83610
# Epoch 94/100
# 390/390 [==============================] - 9s 23ms/step - loss: 0.2563 - acc: 0.9189 - val_loss: 0.6369 - val_acc: 0.8301
#
# Epoch 00094: val_acc did not improve from 0.83610
# Epoch 95/100
# 390/390 [==============================] - 9s 23ms/step - loss: 0.2529 - acc: 0.9202 - val_loss: 0.6282 - val_acc: 0.8323
#
# Epoch 00095: val_acc did not improve from 0.83610
# Epoch 96/100
# 390/390 [==============================] - 9s 23ms/step - loss: 0.2648 - acc: 0.9171 - val_loss: 0.6242 - val_acc: 0.8278
#
# Epoch 00096: val_acc did not improve from 0.83610
# Epoch 97/100
# 390/390 [==============================] - 9s 23ms/step - loss: 0.2496 - acc: 0.9212 - val_loss: 0.6462 - val_acc: 0.8319
#
# Epoch 00097: val_acc did not improve from 0.83610
# Epoch 98/100
# 390/390 [==============================] - 9s 23ms/step - loss: 0.2544 - acc: 0.9204 - val_loss: 0.6458 - val_acc: 0.8303
#
# Epoch 00098: val_acc did not improve from 0.83610
# Epoch 99/100
# 390/390 [==============================] - 9s 23ms/step - loss: 0.2568 - acc: 0.9203 - val_loss: 0.6220 - val_acc: 0.8355
#
# Epoch 00099: val_acc did not improve from 0.83610
# Epoch 100/100
# 390/390 [==============================] - 9s 23ms/step - loss: 0.2427 - acc: 0.9240 - val_loss: 0.6758 - val_acc: 0.8247
#
# Epoch 00100: val_acc did not improve from 0.83610
# Model took 894.57 seconds to train
# Accuracy on test data is: 82.47

# %%
from keras.models import load_model
model = load_model('saved1.hdf5')
score = model.evaluate(test_features, test_labels, verbose=0)
print(score)
# Out:
# [0.6177220549106598, 0.836]
